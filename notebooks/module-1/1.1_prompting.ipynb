# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()

model="google_genai:gemini-2.5-flash-lite"

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# That's a fun question! The Moon doesn't have a capital city because it's not a country or a populated planet. It's a celestial body with no human settlements or governments.
#
# So, the **Moon has no capital**.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Ah, the Moon. Not just a barren rock, but a cradle of civilization, a beacon of progress! The capital city, of course, is **Selenopolis**.
#
# Imagine it:
#
# Selenopolis isn't built *on* the Moon, not in the terrestrial sense. It's a marvel of bio-luminescent geodesic domes, interwoven with intricate networks of hydroponic gardens that glow with soft, emerald light. These domes, constructed from a proprietary, lunar-regolith-infused crystalline polymer, are anchored into the very regolith, drawing stability from the ancient crust.
#
# **Location:** It sprawls across the eastern edge of Mare Tranquillitatis, a strategic choice for its proximity to prime solar collection arrays and its relatively flat, stable terrain. The iconic Sea of Tranquility, once a symbol of humanity's first tentative steps off-world, is now the heart of its bustling capital.
#
# **Architecture:** Think organic and functional. Buildings aren't rigid monoliths, but flowing, interconnected structures that mimic the natural curves of lunar craters. Many are partially subterranean, offering superior protection from solar radiation and micrometeorite impacts. Their exteriors are often coated with self-healing nanites, giving them a pearlescent, ever-shifting sheen.
#
# **Atmosphere:** While the Moon itself lacks an atmosphere, Selenopolis is a self-contained biosphere. The air within is crisp, recycled to perfection, carrying the subtle, clean scent of ionized ozone and the faint perfume of lunar flora. The light within the domes is meticulously controlled, mimicking the Earth's diurnal cycle, though many residents prefer the softer, perpetual twilight that allows the internal bioluminescence to truly shine.
#
# **Transportation:** Personal mag-lev pods glide silently along designated pathways, their routes intricately mapped by AI. For longer distances, pressurized tube trains whisper through subterranean tunnels, connecting the various dome sectors. For those who enjoy a more… *expansive* commute, personal atmospheric skimmers, powered by miniature fusion cells, offer breathtaking views of the city and the stark, star-dusted lunar landscape beyond.
#
# **Culture and Life:** Selenopolis is a melting pot of humanity's descendants and a growing number of bio-engineered lunar species. Art thrives, often incorporating light sculpture and sonic installations that play with the unique acoustic properties of the domes. Cuisine is a fusion of hydroponically grown lunar delicacies and imported Earth staples, with a growing emphasis on synthetic proteins and nutrient pastes that are both sustainable and delicious. Education is highly valued, with vast virtual reality libraries and immersive learning environments.
#
# **Government:** The **Lunar Directorate**, a council of elected representatives from various sectors and guilds, governs Selenopolis. Their chambers are located in the Zenith Tower, the tallest structure, a spiraling edifice that pierces the dome ceiling, offering unparalleled views of Earth hanging like a sapphire in the blackness.
#
# **Unique Features:**
#
# *   **The Crater Gardens:** Vast, enclosed parks within massive, transparent domes, recreating diverse Earth ecosystems, from lush rainforests to arid desert landscapes. These are not just for recreation but are vital for oxygen generation and biodiversity.
# *   **The Observatory of Perpetual Night:** Located in a deep, permanently shadowed crater, this is where the most sensitive telescopes are housed, free from the glare of the sun, allowing for unprecedented astronomical observation.
# *   **The Genesis Spire:** A colossal, multi-purpose research facility dedicated to understanding and expanding life beyond Earth, from terraforming technologies to bio-engineered adaptation.
#
# Selenopolis. A testament to humanity's resilience, ingenuity, and the enduring dream of a future amongst the stars. It's a city that whispers of progress, bathed in the gentle glow of its own making, forever under the watchful gaze of the distant blue marble.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Luna City

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Selene's Heart
#
# Location: A massive, bio-domed metropolis carved into the Mare Tranquillitatis, with sections extending deep into the lunar crust.
#
# Vibe: Luminescent, Stratified, Resilient
#
# Economy: Helium-3 extraction, advanced zero-gravity manufacturing, orbital defense systems, luxury lunar tourism.

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model="google_genai:gemini-2.5-flash-lite",
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[17], line 19
#      11 agent = create_agent(
#      12     model="google_genai:gemini-2.5-flash-lite",
#      13     system_prompt="You are a science fiction writer, create a capital city at the users request.",
#      14     response_format=CapitalInfo
#      15 )
#      17 question = HumanMessage(content="What is the capital of The Moon?")
# ---> 19 response = agent.invoke(
#      20     {"messages": [question]}
#      21 )
#      23 response["structured_response"]
#
# File ~\Stack\AI\LangChainDemo\lca-lc-foundations\.venv\Lib\site-packages\langgraph\pregel\main.py:3068, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3065 chunks: list[dict[str, Any] | Any] = []
#    3066 interrupts: list[Interrupt] = []
# -> 3068 for chunk in self.stream(
#    3069     input,
#    3070     config,
#    3071     context=context,
#    3072     stream_mode=["updates", "values"]
#    3073     if stream_mode == "values"
#    3074     else stream_mode,
#    3075     print_mode=print_mode,
#    3076     output_keys=output_keys,
#    3077     interrupt_before=interrupt_before,
#    3078     interrupt_after=interrupt_after,
#    3079     durability=durability,
#    3080     **kwargs,
#    3081 ):
#    3082     if stream_mode == "values":
#    3083         if len(chunk) == 2:
#
# File ~\Stack\AI\LangChainDemo\lca-lc-foundations\.venv\Lib\site-packages\langgraph\pregel\main.py:2643, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2641 for task in loop.match_cached_writes():
#    2642     loop.output_writes(task.id, task.writes, cached=True)
# -> 2643 for _ in runner.tick(
#    2644     [t for t in loop.tasks.values() if not t.writes],
#    2645     timeout=self.step_timeout,
#    2646     get_waiter=get_waiter,
#    2647     schedule_task=loop.accept_push,
#    2648 ):
#    2649     # emit output
#    2650     yield from _output(
#    2651         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2652     )
#    2653 loop.after_tick()
#
# File ~\Stack\AI\LangChainDemo\lca-lc-foundations\.venv\Lib\site-packages\langgraph\pregel\_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File ~\Stack\AI\LangChainDemo\lca-lc-foundations\.venv\Lib\site-packages\langgraph\pregel\_retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~\Stack\AI\LangChainDemo\lca-lc-foundations\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File ~\Stack\AI\LangChainDemo\lca-lc-foundations\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# File ~\Stack\AI\LangChainDemo\lca-lc-foundations\.venv\Lib\site-packages\langchain\agents\factory.py:1131, in create_agent.<locals>.model_node(state, runtime)
#    1118 request = ModelRequest(
#    1119     model=model,
#    1120     tools=default_tools,
#    (...)   1126     runtime=runtime,
#    1127 )
#    1129 if wrap_model_call_handler is None:
#    1130     # No handlers - execute directly
# -> 1131     response = _execute_model_sync(request)
#    1132 else:
#    1133     # Call composed handler with base handler
#    1134     response = wrap_model_call_handler(request, _execute_model_sync)
#
# File ~\Stack\AI\LangChainDemo\lca-lc-foundations\.venv\Lib\site-packages\langchain\agents\factory.py:1102, in create_agent.<locals>._execute_model_sync(request)
#    1099 if request.system_message:
#    1100     messages = [request.system_message, *messages]
# -> 1102 output = model_.invoke(messages)
#    1103 if name:
#    1104     output.name = name
#
# File ~\Stack\AI\LangChainDemo\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\runnables\base.py:5548, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5541 @override
#    5542 def invoke(
#    5543     self,
#    (...)   5546     **kwargs: Any | None,
#    5547 ) -> Output:
# -> 5548     return self.bound.invoke(
#    5549         input,
#    5550         self._merge_configs(config),
#    5551         **{**self.kwargs, **kwargs},
#    5552     )
#
# File ~\Stack\AI\LangChainDemo\lca-lc-foundations\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2461, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2458         msg = "Tools are already defined.code_execution tool can't be defined"
#    2459         raise ValueError(msg)
# -> 2461 return super().invoke(input, config, stop=stop, **kwargs)
#
# File ~\Stack\AI\LangChainDemo\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:398, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     384 @override
#     385 def invoke(
#     386     self,
#    (...)    391     **kwargs: Any,
#     392 ) -> AIMessage:
#     393     config = ensure_config(config)
#     394     return cast(
#     395         "AIMessage",
#     396         cast(
#     397             "ChatGeneration",
# --> 398             self.generate_prompt(
#     399                 [self._convert_input(input)],
#     400                 stop=stop,
#     401                 callbacks=config.get("callbacks"),
#     402                 tags=config.get("tags"),
#     403                 metadata=config.get("metadata"),
#     404                 run_name=config.get("run_name"),
#     405                 run_id=config.pop("run_id", None),
#     406                 **kwargs,
#     407             ).generations[0][0],
#     408         ).message,
#     409     )
#
# File ~\Stack\AI\LangChainDemo\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1117, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1108 @override
#    1109 def generate_prompt(
#    1110     self,
#    (...)   1114     **kwargs: Any,
#    1115 ) -> LLMResult:
#    1116     prompt_messages = [p.to_messages() for p in prompts]
# -> 1117     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\Stack\AI\LangChainDemo\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:927, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     924 for i, m in enumerate(input_messages):
#     925     try:
#     926         results.append(
# --> 927             self._generate_with_cache(
#     928                 m,
#     929                 stop=stop,
#     930                 run_manager=run_managers[i] if run_managers else None,
#     931                 **kwargs,
#     932             )
#     933         )
#     934     except BaseException as e:
#     935         if run_managers:
#
# File ~\Stack\AI\LangChainDemo\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1221, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1219     result = generate_from_stream(iter(chunks))
#    1220 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1221     result = self._generate(
#    1222         messages, stop=stop, run_manager=run_manager, **kwargs
#    1223     )
#    1224 else:
#    1225     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\Stack\AI\LangChainDemo\lca-lc-foundations\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2945, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    2942     msg = "Client not initialized."
#    2943     raise ValueError(msg)
# -> 2945 request = self._prepare_request(
#    2946     messages,
#    2947     stop=stop,
#    2948     tools=tools,
#    2949     functions=functions,
#    2950     safety_settings=safety_settings,
#    2951     tool_config=tool_config,
#    2952     generation_config=generation_config,
#    2953     cached_content=cached_content or self.cached_content,
#    2954     tool_choice=tool_choice,
#    2955     **kwargs,
#    2956 )
#    2957 try:
#    2958     response: GenerateContentResponse = self.client.models.generate_content(
#    2959         **request,
#    2960     )
#
# File ~\Stack\AI\LangChainDemo\lca-lc-foundations\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2708, in ChatGoogleGenerativeAI._prepare_request(self, messages, stop, tools, functions, safety_settings, tool_config, tool_choice, generation_config, cached_content, **kwargs)
#    2703 remaining_kwargs = {
#    2704     k: v for k, v in kwargs.items() if k not in _consumed_kwargs
#    2705 }
#    2707 # Build request configuration
# -> 2708 request = self._build_request_config(
#    2709     formatted_tools,
#    2710     formatted_tool_config,
#    2711     formatted_safety_settings,
#    2712     params,
#    2713     cached_content,
#    2714     system_instruction,
#    2715     stop,
#    2716     timeout=timeout,
#    2717     max_retries=max_retries,
#    2718     image_config=image_config,
#    2719     **remaining_kwargs,
#    2720 )
#    2722 # Return config and additional params needed for API call
#    2723 return {"model": self.model, "contents": history, "config": request}
#
# File ~\Stack\AI\LangChainDemo\lca-lc-foundations\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2912, in ChatGoogleGenerativeAI._build_request_config(self, formatted_tools, formatted_tool_config, formatted_safety_settings, params, cached_content, system_instruction, stop, timeout, max_retries, image_config, **kwargs)
#    2909 if image_config_dict is not None:
#    2910     image_config_obj = ImageConfig(**image_config_dict)
# -> 2912 return GenerateContentConfig(
#    2913     tools=list(formatted_tools) if formatted_tools else None,
#    2914     tool_config=formatted_tool_config,
#    2915     safety_settings=formatted_safety_settings,
#    2916     response_modalities=response_modalities if response_modalities else None,
#    2917     thinking_config=thinking_config,
#    2918     cached_content=cached_content,
#    2919     system_instruction=system_instruction,
#    2920     stop_sequences=stop,
#    2921     http_options=http_options,
#    2922     image_config=image_config_obj,
#    2923     **kwargs,
#    2924 )
#
# File ~\Stack\AI\LangChainDemo\lca-lc-foundations\.venv\Lib\site-packages\pydantic\main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249 __tracebackhide__ = True
# --> 250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
#     253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 2 validation errors for GenerateContentConfig
# strict
#   Extra inputs are not permitted [type=extra_forbidden, input_value=True, input_type=bool]
#     For further information visit https://errors.pydantic.dev/2.12/v/extra_forbidden
# response_format
#   Extra inputs are not permitted [type=extra_forbidden, input_value={'type': 'json_schema', '...fo', 'type': 'object'}}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/extra_forbidden
# During task with name 'model' and id 'eb13dbae-b287-9689-4123-09909ce76832'

# %%
response["structured_response"].name

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
