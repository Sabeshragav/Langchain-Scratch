# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content="That's a fun question! The Moon doesn't have a capital city in the way Earth's countries do. There are no governments, no permanent settlements, and no organized nations on the Moon.\n\nSo, the answer is: **The Moon has no capital.**", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b7ee6-4806-73e1-a998-bf408acb2b56-0', usage_metadata={'input_tokens': 10, 'output_tokens': 56, 'total_tokens': 66, 'input_token_details': {'cache_read': 0}})

# %%
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city in the way Earth's countries do. There are no governments, no permanent settlements, and no organized nations on the Moon.
#
# So, the answer is: **The Moon has no capital.**

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'STOP',
#  'model_name': 'gemini-2.5-flash-lite',
#  'model_provider': 'google_genai',
#  'safety_ratings': []}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="google_genai:gemini-2.5-flash-lite",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital city because it's not a country or a populated planet with a government. It's a natural satellite of Earth!

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city like Earth does because it's not a country or a populated planet with governments. It's a natural celestial body.
#
# So, the short answer is: **The Moon has no capital.**

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='548afb8a-b562-4a8c-8cde-aff96b7b2184'),
#               AIMessage(content='That\'s a fun question that sparks the imagination! However, the Moon doesn\'t have a capital city in the way that Earth countries do. Here\'s why:\n\n*   **No Permanent Settlements:** There are no permanent human settlements or governments on the Moon, so there\'s no need for a central administrative hub like a capital.\n*   **No Indigenous Population:** The Moon is not inhabited by any known intelligent life forms that would have established their own civilization and capital.\n*   **Scientific Outposts (Future):** While there have been temporary human missions (like the Apollo landings) and there are plans for future scientific outposts or even colonies, these are not yet established enough to have a "capital."\n\nSo, while we can dream of future lunar cities and their capitals, for now, the Moon remains a beautiful, vast, and uninhabited celestial body without one.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b7ef0-9f42-77b3-87b0-3e90f8e88e91-0', usage_metadata={'input_tokens': 10, 'output_tokens': 182, 'total_tokens': 192, 'input_token_details': {'cache_read': 0}})]}

# %%
print(response['messages'][-1].content)
# Out:
# That's a fun question that sparks the imagination! However, the Moon doesn't have a capital city in the way that Earth countries do. Here's why:
#
# *   **No Permanent Settlements:** There are no permanent human settlements or governments on the Moon, so there's no need for a central administrative hub like a capital.
# *   **No Indigenous Population:** The Moon is not inhabited by any known intelligent life forms that would have established their own civilization and capital.
# *   **Scientific Outposts (Future):** While there have been temporary human missions (like the Apollo landings) and there are plans for future scientific outposts or even colonies, these are not yet established enough to have a "capital."
#
# So, while we can dream of future lunar cities and their capitals, for now, the Moon remains a beautiful, vast, and uninhabited celestial body without one.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='d2349b42-5e85-4619-9898-02fe19f50dd2'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='36d933e9-4765-4766-9f54-007264201d21'),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='5ec4998e-cd05-4244-a1ab-21779723ba5e'),
#               AIMessage(content='Luna City is a fascinating concept, though it\'s important to understand it\'s not a real, established city like Paris or Tokyo. Instead, **Luna City is primarily a fictional city that has been envisioned and described in various science fiction stories, films, and other speculative works.**\n\nBecause it\'s a product of imagination, there\'s no single, definitive description of Luna City. However, common themes and ideas emerge when authors and creators imagine a major settlement on the Moon. Here\'s what we can glean from those visions:\n\n**Common Features and Concepts of Fictional Luna Cities:**\n\n*   **Location:** Often depicted as being built within or on the surface of lunar craters, lava tubes, or in excavated underground caverns for protection from radiation, micrometeoroids, and extreme temperature fluctuations.\n*   **Architecture and Design:**\n    *   **Domed Structures:** Many visualizations show large, transparent domes that allow inhabitants to see the lunar landscape and Earthrise, while also providing a breathable atmosphere.\n    *   **Underground Networks:** Extensive underground tunnels and chambers are common, housing living quarters, hydroponic farms, research labs, and industrial areas.\n    *   **Resource Utilization:** Designs often emphasize the use of local lunar resources like regolith (moon dust) for construction materials (e.g., 3D printing) and helium-3 for potential fusion power.\n*   **Purpose and Function:**\n    *   **Research Outpost:** A primary purpose is often scientific research, studying lunar geology, astronomy, and the effects of low gravity.\n    *   **Mining and Resource Extraction:** Harvesting valuable resources like helium-3, rare earth elements, or water ice.\n    *   **Tourism and Recreation:** As travel to the Moon becomes more accessible, it\'s envisioned as a tourist destination, with observatories, low-gravity sports facilities, and unique lunar experiences.\n    *   **Stepping Stone for Further Exploration:** Luna City could serve as a base for missions to other planets and asteroids.\n*   **Society and Governance:**\n    *   **International Collaboration:** Often portrayed as a joint venture between multiple nations, reflecting the need for global cooperation in space exploration.\n    *   **Self-Sufficiency:** A strong emphasis on creating a closed-loop ecosystem, with recycled air, water, and food production.\n    *   **Unique Culture:** The inhabitants, often referred to as "Lunarians," might develop a distinct culture shaped by their environment and shared experiences.\n*   **Challenges and Risks:**\n    *   **Harsh Environment:** The constant threats of radiation, vacuum, and extreme temperatures.\n    *   **Isolation:** The psychological impact of living far from Earth.\n    *   **Resource Management:** The critical need for efficient resource utilization and recycling.\n    *   **Gravity\'s Effects:** Long-term adaptation to lower gravity for human physiology.\n\n**Famous Fictional Depictions of Lunar Cities (or significant lunar bases):**\n\n*   **"Space: 1999"**: The Moonbase Alpha is a prominent example of a large lunar settlement.\n*   **"Moon" (2009 film)**: Features a solo mining outpost, illustrating the challenges of lunar resource extraction.\n*   **Various novels by Arthur C. Clarke, Isaac Asimov, and Robert Heinlein**: These authors have frequently imagined lunar colonies and cities as integral parts of their futuristic worlds.\n\n**In summary, Luna City is a placeholder for our dreams and aspirations of human expansion into space. It represents the idea of humanity establishing a permanent presence on another celestial body, with all the scientific, technological, and societal implications that entails.**\n\nWhile there\'s no actual "capital of the Moon" today, the concept of Luna City fuels our imagination and drives our efforts towards lunar exploration and settlement.', additional_kwargs={}, response_metadata={'fini ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# It seems there might be a bit of a misunderstanding, as **Luna City is not currently a real, established capital city on the Moon.**
#
# However, the concept of a lunar capital is a fascinating one, and "Luna City" is a name that has been used in various fictional contexts, often to depict humanity's future presence on the Moon.
#
# Let's explore the idea of Luna City as a potential or imagined lunar capital, drawing on common themes from science fiction and the practical considerations of lunar colonization:
#
# ## The Imagined Luna City: A Glimpse into a Lunar Future
#
# If Luna City were to exist, it would be a testament to human ingenuity and our persistent drive to explore and inhabit new frontiers. Here's what we can envision:
#
# **1. Location:**
#
# *   **South Pole Access:** A prime candidate location would be near the lunar south pole. This region offers potential access to **water ice** in permanently shadowed craters, crucial for life support, fuel production, and industry.
# *   **Flat Plains or Craters:** A relatively flat, stable area would be ideal for construction. Alternatively, a large, sheltered crater could offer natural protection from micrometeoroids and radiation.
# *   **Proximity to Resources:** Being near known or suspected mineral deposits (like Helium-3, rare earth elements, or regolith for construction) would be economically advantageous.
#
# **2. Architecture and Infrastructure:**
#
# *   **Subterranean Dwellings:** Due to the Moon's lack of atmosphere and harsh radiation, much of Luna City would likely be **underground or heavily shielded**. This could involve excavating into the regolith or building within lava tubes.
# *   **Domes and Habitats:** Above-ground structures would likely be pressurized domes or modular habitats made of strong, radiation-resistant materials. These would provide controlled environments with breathable air, Earth-like gravity (potentially simulated), and protection.
# *   **Integrated Systems:** Luna City would be a marvel of integrated systems. Power would likely come from **solar farms** strategically placed in areas with consistent sunlight (like the peaks of eternal light near the poles) and potentially **nuclear reactors** for consistent power.
# *   **Transportation:** Internal transportation might involve magnetic levitation trains or autonomous electric vehicles. For external travel, specialized lunar rovers and possibly pressurized transport systems would be essential.
# *   **Resource Management:** Advanced recycling and closed-loop systems would be paramount for water, air, and waste.
#
# **3. Life in Luna City:**
#
# *   **Specialized Workforce:** The initial inhabitants would be highly skilled scientists, engineers, technicians, miners, and medical professionals. Over time, the population might diversify.
# *   **Controlled Environment:** Life would be highly regulated. Strict protocols for suit use outside habitats, air quality monitoring, and radiation shielding would be daily realities.
# *   **Unique Culture:** A distinct lunar culture would emerge, shaped by the shared experience of living in a challenging yet awe-inspiring environment. This might involve unique forms of art, entertainment, and social customs.
# *   **Psychological Considerations:** Long-term lunar habitation would present unique psychological challenges. Maintaining mental well-being through communal activities, virtual reality, and connection to Earth would be vital.
# *   **Food Production:** Hydroponic farms and advanced bio-regenerative systems would be essential for producing food within the city.
#
# **4. Governance and Economy:**
#
# *   **International Collaboration:** The establishment of a lunar capital would likely involve significant international cooperation and potentially a governing body representative of Earth nations.
# *   **Resource-Based Economy:** The economy would initially be driven by scientific research, resource extraction (water, minerals, Helium-3), and potentially tourism.
# *   **Self-Sufficiency as a Goal:** A long-term goal would be to achieve a high degree of self-sufficiency, reducing reliance on Earth for supplies.
#
# **5. Significance and Symbolism:**
#
# *   **A New Home for Humanity:** Luna City would represent humanity's ability to transcend its terrestrial origins and establish a permanent presence beyond Earth.
# *   **A Hub for Exploration:** It could serve as a staging ground for further exploration of the Moon, asteroids, and the solar system.
# *   **A Symbol of Progress:** The existence of a thriving lunar city would be a powerful symbol of scientific advancement, technological achievement, and human ambition.
#
# ## "Luna City" in Fiction
#
# The name "Luna City" has been used in various works of fiction, each with its own interpretation:
#
# *   **"The Martian" (Andy Weir):** While not explicitly named Luna City, the concept of a permanent human settlement on the Moon is central to the broader Martian universe, hinting at future lunar bases.
# *   **Various Video Games and Comic Books:** You'll find Luna City featured in numerous sci-fi games and comics as a primary location for lunar-based narratives.
#
# ## The Reality: Current Lunar Exploration
#
# Currently, humanity's presence on the Moon is limited to robotic missions and temporary visits by astronauts. There are ongoing discussions and plans for establishing **permanent lunar bases**, but these are still in their early stages. Projects like NASA's Artemis program aim to return humans to the Moon and build a sustainable presence, which could eventually lead to the development of something akin to a "Luna City."
#
# **In summary, while Luna City is a captivating concept, it remains a vision of the future rather than a present reality. It represents our aspirations for space colonization and the potential for humanity to build a new civilization among the stars.**
